# %% [markdown]
# <a href="https://colab.research.google.com/github/Sujithkasan/customer-support-ticket-triage/blob/main/Week1_Customer_Support_Triage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("/content/customer_support_tickets.csv")

print("Dataset imported successfully")
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])

df.head()
# Out:
# Dataset imported successfully
# Number of rows: 8469
# Number of columns: 17
#    Ticket ID        Customer Name              Customer Email  Customer Age  \
# 0          1        Marisa Obrien  carrollallison@example.com            32
# 1          2         Jessica Rios    clarkeashley@example.com            42
# 2          3  Christopher Robbins   gonzalestracy@example.com            48
# 3          4     Christina Dillon    bradleyolson@example.org            27
# 4          5    Alexander Carroll     bradleymark@example.com            67
#
#   Customer Gender Product Purchased Date of Purchase      Ticket Type  \
# 0           Other        GoPro Hero       2021-03-22  Technical issue
# 1          Female       LG Smart TV       2021-05-22  Technical issue
# 2           Other          Dell XPS       2020-07-14  Technical issue
# 3          Female  Microsoft Office       2020-11-13  Billing inquiry
# 4          Female  Autodesk AutoCAD       2020-02-04  Billing inquiry
#
#              Ticket Subject  \
# 0             Product setup
# 1  Peripheral compatibility
# 2           Network problem
# 3            Account access
# 4                 Data loss
#
#                                   Ticket Description  \
# 0  I'm having an issue with the {product_purchase...
# 1  I'm having an issue with the {product_purchase...
# 2  I'm facing a problem with my {product_purchase...
# 3  I'm having an issue with the {product_purchase...
# 4  I'm having an issue with the {product_purchase...
#
#                Ticket Status                                     Resolution  \
# 0  Pending Customer Response                                            NaN
# 1  Pending Customer Response                                            NaN
# 2                     Closed   Case maybe show recently my computer follow.
# 3                     Closed  Try capital clearly never color toward story.
# 4                     Closed                    West decision evidence bit.
#
#   Ticket Priority Ticket Channel  First Response Time   Time to Resolution  \
# 0        Critical   Social media  2023-06-01 12:15:36                  NaN
# 1        Critical           Chat  2023-06-01 16:45:38                  NaN
# 2             Low   Social media  2023-06-01 11:14:38  2023-06-01 18:05:38
# 3             Low   Social media  2023-06-01 07:29:40  2023-06-01 01:57:40
# 4             Low          Email  2023-06-01 00:12:42  2023-06-01 19:53:42
#
#    Customer Satisfaction Rating
# 0                           NaN
# 1                           NaN
# 2                           3.0
# 3                           3.0
# 4                           1.0

# %%
import pandas as pd


df = pd.read_csv("/content/customer_support_tickets.csv")


text_col = [c for c in df.columns if "message" in c.lower()
            or "issue" in c.lower()
            or "description" in c.lower()][0]

time_col = [c for c in df.columns if "date" in c.lower()
            or "time" in c.lower()][0]


df["clean_message"] = (
    df[text_col]
    .astype(str)
    .str.lower()
    .str.replace(r"[^a-z0-9 ]", " ", regex=True)
    .str.replace(r"\s+", " ", regex=True)
    .str.strip()
)


df["issue_type"] = "GENERAL"

df.loc[df["clean_message"].str.contains("payment|paid|card|upi|transaction"), "issue_type"] = "PAYMENT"
df.loc[df["clean_message"].str.contains("login|password|signin|otp"), "issue_type"] = "LOGIN"
df.loc[df["clean_message"].str.contains("delivery|shipping|courier|late"), "issue_type"] = "DELIVERY"
df.loc[df["clean_message"].str.contains("refund|return|money back"), "issue_type"] = "REFUND"
df.loc[df["clean_message"].str.contains("bug|error|crash|problem|not working"), "issue_type"] = "BUG"


priority_map = {
    "PAYMENT": "P0", "BUG": "P0",
    "LOGIN": "P1", "REFUND": "P1",
    "DELIVERY": "P2", "GENERAL": "P3"
}
df["priority"] = df["issue_type"].map(priority_map)

sla_map = {"P0": 4, "P1": 8, "P2": 24, "P3": 72}
df["sla_hours"] = df["priority"].map(sla_map)

df[time_col] = pd.to_datetime(df[time_col], errors="coerce")
df["due_time"] = df[time_col] + pd.to_timedelta(df["sla_hours"], unit="h")

df.to_csv("/content/final_customer_support_output.csv", index=False)

print("SUCCESS")
print("Customer name column preserved (if present)")
print(df["issue_type"].value_counts())
# Out:
# SUCCESS
# Customer name column preserved (if present)
# issue_type
# GENERAL     3701
# BUG         3592
# DELIVERY     825
# REFUND       180
# PAYMENT      122
# LOGIN         49
# Name: count, dtype: int64

# %%
import pandas as pd
df = pd.read_csv("/content/final_customer_support_output.csv")
print("File loaded successfully")
# Out:
# File loaded successfully

# %%
df.columns
# Out:
# Index(['Ticket ID', 'Customer Name', 'Customer Email', 'Customer Age',
#        'Customer Gender', 'Product Purchased', 'Date of Purchase',
#        'Ticket Type', 'Ticket Subject', 'Ticket Description', 'Ticket Status',
#        'Resolution', 'Ticket Priority', 'Ticket Channel',
#        'First Response Time', 'Time to Resolution',
#        'Customer Satisfaction Rating', 'clean_message', 'issue_type',
#        'priority', 'sla_hours', 'due_time'],
#       dtype='object')

# %%
import pandas as pd

df = pd.read_csv("/content/final_customer_support_output.csv")
df.head(20)
# Out:
#     Ticket ID        Customer Name              Customer Email  Customer Age  \
# 0           1        Marisa Obrien  carrollallison@example.com            32
# 1           2         Jessica Rios    clarkeashley@example.com            42
# 2           3  Christopher Robbins   gonzalestracy@example.com            48
# 3           4     Christina Dillon    bradleyolson@example.org            27
# 4           5    Alexander Carroll     bradleymark@example.com            67
# 5           6      Rebecca Fleming     sheenasmith@example.com            53
# 6           7    Jacqueline Wright     donaldkeith@example.org            24
# 7           8           Denise Lee    joelwilliams@example.com            23
# 8           9       Nicolas Wilson        joshua24@example.com            60
# 9          10       William Dawson          clopez@example.com            27
# 10         11        Joseph Moreno          mbrown@example.org            48
# 11         12       Brandon Arnold       davisjohn@example.net            51
# 12         13          Tamara Hahn   jensenwilliam@example.net            27
# 13         14        Sandra Barnes     gwendolyn51@example.net            65
# 14         15             Amy Hill    medinasteven@example.net            48
# 15         16      Elizabeth Foley           amy41@example.net            18
# 16         17        Julia Salazar  watkinsbarbara@example.com            63
# 17         18      Joshua Castillo    mooredeborah@example.org            56
# 18         19          Wendy Davis        brenda20@example.net            19
# 19         20    Jeffrey Robertson      jameslopez@example.com            39
#
#    Customer Gender               Product Purchased Date of Purchase  \
# 0            Other                      GoPro Hero       2021-03-22
# 1           Female                     LG Smart TV       2021-05-22
# 2            Other                        Dell XPS       2020-07-14
# 3           Female                Microsoft Office       2020-11-13
# 4           Female                Autodesk AutoCAD       2020-02-04
# 5             Male                Microsoft Office       2020-07-28
# 6            Other               Microsoft Surface       2020-02-23
# 7             Male              Philips Hue Lights       2020-08-09
# 8            Other         Fitbit Versa Smartwatch       2020-07-16
# 9             Male            Dyson Vacuum Cleaner       2020-03-06
# 10            Male                 Nintendo Switch       2021-01-19
# 11            Male       Microsoft Xbox Controller       2021-10-24
# 12           Other  Nintendo Switch Pro Controller       2021-05-26
# 13           Other                 Nest Thermostat       2020-07-13
# 14          Female                Sony PlayStation       2020-02-29
# 15           Other             GoPro Action Camera       2021-06-24
# 16           Other                            Xbox       2021-10-13
# 17          Female       Microsoft Xbox Controller       2020-09-07
# 18            Male              LG Washing Machine       2021-09-23
# 19          Female                       Canon EOS       2021-03-08
#
#              Ticket Type            Ticket Subject  \
# 0        Technical issue             Product setup
# 1        Technical issue  Peripheral compatibility
# 2        Technical issue           Network problem
# 3        Billing inquiry            Account access
# 4        Billing inquiry                 Data loss
# 5   Cancellation request             Payment issue
# 6        Product inquiry            Refund request
# 7         Refund request              Battery life
# 8        Technical issue      Installation support
# 9         Refund request             Payment issue
# 10  Cancellation request                 Data loss
# 11       Product inquiry              Software bug
# 12       Technical issue            Hardware issue
# 13       Technical issue             Product setup
# 14       Billing inquiry             Product setup
# 15       Billing inquiry    Product recommendation
# 16       Product inquiry            Account access
# 17       Product inquiry             Payment issue
# 18       Product inquiry  Peripheral compatibility
# 19        Refund request              Software bug
#
#                                    Ticket Description  ... Ticket Priority  \
# 0   I'm having an issue with the {product_purchase...  ...        Critical
# 1   I'm having an issue with the {product_purchase...  ...        Critical
# 2   I'm facing a problem with my {product_purchase...  ...             Low
# 3   I'm having an issue with the {product_purchase...  ...             Low
# 4   I'm having an issue with the {product_purchase...  ...             Low
# 5   I'm facing a problem with my {product_purchase...  ...             Low
# 6   I'm unable to access my {product_purchased} ac...  ...        Critical
# 7   I'm having an issue with the {product_purchase...  ...        Critical
# 8   I'm having an issue with the {product_purchase...  ...             Low
# 9   My {product_purchased} is making strange noise...  ...        Critical
# 10  I'm having an issue with the {product_purchase...  ...            High
# 11  I'm having an issue with the {product_purchase...  ...            High
# 12  I'm having an issue with the {product_purchase...  ...             Low
# 13  I've recently set up my {product_purchased}, b...  ...             Low
# 14  I'm having an issue with the {product_purchase...  ...            High
# 15  I'm having an issue with the {product_purchase...  ...            High
# 16  I'm having an issue with the {product_purchase...  ...        Critical
# 17  I'm having an issue with the {product_purchase...  ...            High
# 18  I'm having an issue with the {product_purchase...  ...            High
# 19  I'm having an issue with the {product_purchase...  ...             Low
#
#    Ticket Channel  First Response Time   Time to Resolution  \
# 0    Social media  2023-06-01 12:15:36                  NaN
# 1            Chat  2023-06-01 16:45:38                  NaN
# 2    Social media  2023-06-01 11:14:38  2023-06-01 18:05:38
# 3    Social media  2023-06-01 07:29:40  2023-06-01 01:57:40
# 4           Email  2023-06-01 00:12:42  2023-06-01 19:53:42
# 5    Social media                  NaN                  NaN
# 6    Social media                  NaN                  NaN
# 7    Social media                  NaN                  NaN
# 8    Social media  2023-06-01 10:32:47                  NaN
# 9           Phone  2023-06-01 09:25:48                  NaN
# 10          Phone  2023-06-01 17:46:49  2023-05-31 23:51:49
# 11           Chat  2023-06-01 12:05:51  2023-06-01 09:27:51
# 12           Chat  2023-06-01 19:03:53                  NaN
# 13           Chat  2023-06-01 20:34:54                  NaN
# 14           Chat  2023-06-01 06:22:55  2023-05-31 23:08:55
# 15   Social media  2023-06-01 15:09:57                  NaN
# 16           Chat  2023-06-01 19:46:59  2023-06-01 15:58:59
# 17           Chat  2023-06-01 21:05:01                  NaN
# 18   Social media                  NaN                  NaN
# 19           Chat  2023-06-01 00:46:04  2023-06-01 20:29:04
#
#    Customer Satisfaction Rating  \
# 0                           NaN
# 1                           NaN
# 2                           3.0
# 3                           3.0
# 4                           1.0
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          1.0
# 11                          1.0
# 12                          NaN
# 13                          NaN
# 14                          4.0
# 15                          NaN
# 16                          4.0
# 17                          NaN
# 18                          NaN
# 19                          5.0
#
#                                         clean_message  issue_type priority  \
# 0   i m having an issue with the product purchased...     GENERAL       P3
# 1   i m having an issue with the product purchased...     GENERAL       P3
# 2   i m facing a problem with my product purchased...         BUG       P0
# 3   i m having an issue with the product purchased...         BUG       P0
# 4   i m having an issue with the product purchased...    DELIVERY       P2
# 5   i m facing a problem with my product purchased...         BUG       P0
# 6   i m unable to access my product purchased acco...         BUG       P0
# 7   i m having an issue with the product purchased...         BUG       P0
# 8   i m having an issue with the product purchased...    DELIVERY       P2
# 9   my product purchased is making strange noises ...     GENERAL       P3
# 10  i m having an issue with the product purchased...     GENERAL       P3
# 11  i m having an issue with the product purchased...         BUG       P0
# 12  i m having an issue with the product purchased...     GENERAL       P3
# 13  i ve recently set up my product purchased but ...     GENERAL       P3
# 14  i m having an issue with the product purchased...    DELIVERY       P2
# 15  i m having an issue with the product purchased...     PAYMENT       P0
# 16  i m having an issue with the product purchased...     GENERAL       P3
# 17  i m having an issue with the product purchased...         BUG       P0
# 18  i m having an issue with the product purchased...     GENERAL       P3
# 19  i m having an issue with the product purchased...     GENERAL       P3
#
#    sla_hours             due_time
# 0         72  2021-03-25 00:00:00
# 1         72  2021-05-25 00:00:00
# 2          4  2020-07-14 04:00:00
# 3          4  2020-11-13 04:00:00
# 4         24  2020-02-05 00:00:00
# 5          4  2020-07-28 04:00:00
# 6          4  2020-02-23 04:00:00
# 7          4  2020-08-09 04:00:00
# 8         24  2020-07-17 00:00:00
# 9         72  2020-03-09 00:00:00
# 10        72  2021-01-22 00:00:00
# 11         4  2021-10-24 04:00:00
# 12        72  2021-05-29 00:00:00
# 13        72  2020-07-16 00:00:00
# 14        24  2020-03-01 00:00:00
# 15         4  2021-06-24 04:00:00
# 16        72  2021-10-16 00:00:00
# 17         4  2020-09-07 04:00:00
# 18        72  2021-09-26 00:00:00
# 19        72  2021-03-11 00:00:00
#
# [20 rows x 22 columns]
